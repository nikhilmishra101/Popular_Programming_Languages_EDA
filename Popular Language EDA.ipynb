# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/2.1 QueryResults.csv",names=['DATE','TAG','POSTS'],header=0)

# %% [markdown]
# # Data preprocessing

# %%
data.head()
# Out:
#                   DATE         TAG  POSTS
# 0  2008-07-01 00:00:00          c#      3
# 1  2008-08-01 00:00:00    assembly      8
# 2  2008-08-01 00:00:00  javascript    162
# 3  2008-08-01 00:00:00           c     85
# 4  2008-08-01 00:00:00      python    124

# %%
data.tail()
# Out:
#                      DATE    TAG  POSTS
# 1986  2020-07-01 00:00:00      r   5694
# 1987  2020-07-01 00:00:00     go    743
# 1988  2020-07-01 00:00:00   ruby    775
# 1989  2020-07-01 00:00:00   perl    182
# 1990  2020-07-01 00:00:00  swift   3607

# %% [markdown]
# # Number of rows and columns

# %%
data.shape
# Out:
# (1991, 3)

# %% [markdown]
# # Number of entries in each column

# %%
data.count()
# Out:
# DATE     1991
# TAG      1991
# POSTS    1991
# dtype: int64

# %% [markdown]
# # Number of posts per tag

# %%
data.groupby('TAG').sum()
# Out:
#               POSTS
# TAG
# assembly      34852
# c            336042
# c#          1423530
# c++          684210
# delphi        46212
# go            47499
# java        1696403
# javascript  2056510
# perl          65286
# php         1361988
# python      1496210
# r            356799
# ruby         214582
# swift        273055

# %% [markdown]
# # How many months of data exist per language

# %%
data.groupby('TAG').count()
# Out:
#             DATE  POSTS
# TAG
# assembly     144    144
# c            144    144
# c#           145    145
# c++          144    144
# delphi       144    144
# go           129    129
# java         144    144
# javascript   144    144
# perl         144    144
# php          144    144
# python       144    144
# r            142    142
# ruby         144    144
# swift        135    135

# %% [markdown]
# # Convert string to datetime object

# %%
type(data['DATE'][1])
# Out:
# str

# %%
data.head()
# Out:
#                   DATE         TAG  POSTS
# 0  2008-07-01 00:00:00          c#      3
# 1  2008-08-01 00:00:00    assembly      8
# 2  2008-08-01 00:00:00  javascript    162
# 3  2008-08-01 00:00:00           c     85
# 4  2008-08-01 00:00:00      python    124

# %%
data['DATE'] = pd.to_datetime(data['DATE'])

# %%
data.head()
# Out:
#         DATE         TAG  POSTS
# 0 2008-07-01          c#      3
# 1 2008-08-01    assembly      8
# 2 2008-08-01  javascript    162
# 3 2008-08-01           c     85
# 4 2008-08-01      python    124

# %%
reshaped_df = data.pivot(index='DATE',columns='TAG',values='POSTS')

# %%
reshaped_df.head()
# Out:
# TAG         assembly      c      c#    c++  ...  python    r   ruby  swift
# DATE                                        ...
# 2008-07-01       NaN    NaN     3.0    NaN  ...     NaN  NaN    NaN    NaN
# 2008-08-01       8.0   85.0   511.0  164.0  ...   124.0  NaN   73.0    NaN
# 2008-09-01      28.0  321.0  1649.0  755.0  ...   542.0  6.0  290.0    NaN
# 2008-10-01      15.0  303.0  1989.0  811.0  ...   510.0  NaN  249.0    NaN
# 2008-11-01      17.0  259.0  1730.0  735.0  ...   452.0  1.0  160.0    NaN
#
# [5 rows x 14 columns]

# %%
reshaped_df.shape
# Out:
# (145, 14)

# %%
reshaped_df.columns
# Out:
# Index(['assembly', 'c', 'c#', 'c++', 'delphi', 'go', 'java', 'javascript',
#        'perl', 'php', 'python', 'r', 'ruby', 'swift'],
#       dtype='object', name='TAG')

# %%
reshaped_df.count()
# Out:
# TAG
# assembly      144
# c             144
# c#            145
# c++           144
# delphi        144
# go            129
# java          144
# javascript    144
# perl          144
# php           144
# python        144
# r             142
# ruby          144
# swift         135
# dtype: int64

# %% [markdown]
# # Replace NAN values with 0

# %%
reshaped_df.fillna(0,inplace=True) #The inplace argument means that we are updating reshaped_df

# %%
reshaped_df.isna().values.any() #check for any null value in the dataset
# Out:
# False

# %% [markdown]
# # Data Visualisation

# %%
roll_df = reshaped_df.rolling(window=12).mean()

plt.figure(figsize=(16,10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Date',fontsize=20)
plt.ylabel('Number of posts',fontsize=20)
plt.ylim(0,35000)
for column in roll_df.columns:
  plt.plot(roll_df.index,roll_df[column],linewidth=3,label=roll_df[column].name)

plt.legend(fontsize=16)
plt.show()

# %% [markdown]
# # It shows that python has gain the most popularity in the recent years and python is the most trending language in 2020-2021
